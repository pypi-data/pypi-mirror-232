# %%
from rsidatasciencetools.azureutils.azurerun import AzureMLRun

# from os import path, environ

# %%
arun = AzureMLRun('/home/nick/Work/code/DataScienceTools/dstools/azureutils/example_run/',
                  # env_from_yaml_file=True,use_docker=True,
                  # local=True,
                  debug=1)
arun.setup_run()
# arun
# Out:
# /home/nick/Work/code/DataScienceTools/dstools/config/baseconfig.py:162: UserWarning: for  type: YmlConfig found more than one (yml)  file in this directory, using first file found
#   warn((f'for {self.base_str} type: {self.__class__.__name__} '
# /home/nick/Work/code/DataScienceTools/dstools/azureutils/azurerun.py:348: UserWarning: compute node type specified when compute node name also specified, if the node name exists, then the node type specified will be ignored unless
#   warn(('compute node type specified when compute node name '
# /home/nick/Work/code/DataScienceTools/dstools/config/baseconfig.py:162: UserWarning: for *config type: AzureConfig found more than one (json) *config file in this directory, overriding / replacing according to read-in order
#   warn((f'for {self.base_str} type: {self.__class__.__name__} '
# found SP credentials in config file(s)
# conda dep:  ['matplotlib', 'numpy', 'packaging', 'pandas', 'pip', 'python==3.9.7', 'scikit-learn']
# ...

# %%
arun.yaml_config
# Out:
# YmlConfig | {
#    name:train-on-amlcompute
#    model_name:sklearn-ridge-regr-diabetes
#    env_name:sklearn-pandas-x
#    image:mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.2-cudnn8-ubuntu18.04
#    service_name:sklearn-test-diabetes
#    local:['example_imports', '../../../dstools']
#    exclude:['example_run']
#    wheel:['../../../dist/DataScienceTools-0.0.4-py2.py3-none-any.whl']
#    dependencies:['python==3.9.7', 'scikit-learn', 'pandas', 'numpy', 'matplotlib', 'packaging', 'pip', {'pip': ['mlflow', 'azureml', 'azureml-core', 'azureml-defaults', 'azureml-contrib-services', 'azureml-contrib-dataset', 'azureml-mlflow', 'inference-schema', 'sqlalchemy', 'pymssql']}] }

# %%
arun.train_model(debug=False)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/anaconda3/envs/core/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/anaconda3/envs/core/lib/python3.9/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~/anaconda3/envs/core/lib/python3.9/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# ...

# %%
# path.dirname(arun.yaml_config.file_loc)
# Out:
# '/home/nick/Work/code/DataScienceTools/dstools/azureutils/example_run'

# %%
arun.metrics()
# Out:
# {}
