# %%
from azureml.core.webservice import LocalWebservice
from azureml.core.model import InferenceConfig
from azureml.core.environment import Environment
from azureml.core import Workspace
from azureml.core.model import Model

from glob import glob
from os import path

from rsidatasciencetools.azureutils.azurerun import AzureMLRun

# %%
import os
path.abspath(os.curdir)
# Out:
# '/mnt/c/Users/NickRoseveare/Documents/Work/UbuntuVM/code/DataScienceTools/dstools/azureutils/example_run'

# %%
arun = AzureMLRun('./',yaml='./train-in-azure.yml',debug=1)
arun.setup_run()
# Out:
# /home/nick/Work/code/DataScienceTools/dstools/azureutils/azurerun.py:345: UserWarning: compute node type specified when compute node name also specified, if the node name exists, then the node type specified will be ignored unless
#   warn(('compute node type specified when compute node name '
# /home/nick/Work/code/DataScienceTools/dstools/config/baseconfig.py:162: UserWarning: for *config type: AzureConfig found more than one (json) *config file in this directory, overriding / replacing according to read-in order
#   warn((f'for {self.base_str} type: {self.__class__.__name__} '
# found SP credentials in config file(s)
# conda dep:  ['matplotlib', 'numpy', 'packaging', 'pandas', 'pip', 'python==3.9.7', 'scikit-learn']
# pip dep:  ['azureml', 'azureml-contrib-dataset', 'azureml-contrib-services', 'azureml-core', 'azureml-defaults', 'azureml-mlflow', 'inference-schema', 'mlflow', 'pip', 'pymssql', 'scikit-learn-intelex', 'sqlalchemy']
# ...

# %%
# dk_img = 'mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.2-cudnn8-ubuntu18.04'

# %%
d = '/home/nick/Work/code/DataScienceTools/dstools/azureutils/example_run/'
files = glob(path.join(d,'azure_temp*'))
if files:
    newest_folder = sorted(files,key=lambda fn: fn.split('_')[-1])[-1]

arun = AzureMLRun(d, project_folder=newest_folder, local=True, debug=1,
                  yaml='./train-in-azure.yml')
arun.setup_run(debug=1)
# Out:
# found SP credentials in config file(s)
# conda dep:  ['matplotlib', 'numpy', 'packaging', 'pandas', 'pip', 'python==3.9.7', 'scikit-learn']
# pip dep:  ['azureml', 'azureml-contrib-dataset', 'azureml-contrib-services', 'azureml-core', 'azureml-defaults', 'azureml-mlflow', 'inference-schema', 'mlflow', 'pip', 'pymssql', 'scikit-learn-intelex', 'sqlalchemy']
# wheel pkgs:  ['../../../dist/DataScienceTools-0.0.3-py2.py3-none-any.whl']
# /home/nick/Work/code/DataScienceTools/dstools/azureutils/azurerun.py:460: UserWarning: found matching environement to use: sklearn-pandas-x
#   warn(f'found matching environement to use: {self.azure_env_name}')
# /home/nick/Work/code/DataScienceTools/dstools/azureutils/azurerun.py:266: UserWarning: using preexisting project folder, skipping setup of run script and project folder
#   warn('using preexisting project folder, skipping setup '
# Using local compute resource to execute run in docker container.
# ...

# %%
arun.deploy_model(debug=True)
# Out:
# source directory /mnt/c/Users/NickRoseveare/Documents/Work/UbuntuVM/code/DataScienceTools/dstools/azureutils/example_run/azure_temp-run_train-on-amlcompute_1661797344 doesn't exist.
# ...
# Generating Docker build context.
# 2022/09/09 16:43:32 Downloading source code...
# 2022/09/09 16:43:33 Finished downloading source code
# 2022/09/09 16:43:34 Creating Docker network: acb_default_network, driver: 'bridge'
# 2022/09/09 16:43:34 Successfully set up Docker network: acb_default_network
# 2022/09/09 16:43:34 Setting up Docker configuration...
# 2022/09/09 16:43:35 Successfully set up Docker configuration
# 2022/09/09 16:43:35 Logging in to registry: b1b599e7259e47adb1aff06554c7d857.azurecr.io
# 2022/09/09 16:43:35 Successfully logged into b1b599e7259e47adb1aff06554c7d857.azurecr.io
# 2022/09/09 16:43:35 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2022/09/09 16:43:35 Scanning for dependencies...
# ...

# %%
arun.local_run
# Out:
# True

# %%
# other model example
ws = Workspace.from_config()
model = Model(ws, 'sklearn_mnist')

myenv = Environment.get(workspace=ws, name="sklearn-pandas-x")
inference_config = InferenceConfig(entry_script="score.py", environment=myenv)

deployment_config = LocalWebservice.deploy_configuration(port=6789)

local_service = Model.deploy(workspace=ws, 
                       name='sklearn-mnist-local', 
                       models=[model], 
                       inference_config=inference_config, 
                       deployment_config = deployment_config)

local_service.wait_for_deployment(show_output=True)
print(f"Scoring URI is : {local_service.scoring_uri}")
