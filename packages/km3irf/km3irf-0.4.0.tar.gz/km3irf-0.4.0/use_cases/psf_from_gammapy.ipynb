# %% [markdown]
# ## Test of PSF from gammapy
#
# two modules were copied from `gammapy v0.17`
# - `psf_3d.py`
# - `psf_table.py`
#
# Dependencies from `gammapy` were illiminated.

# %%
import km3irf

# %%
km3irf.__version__
# Out:
# '0.3.1.dev12+g625aae8'

# %%
data_dict = km3irf.list_data()
data_dict
# Out:
# {'aeff.fits': 'D:\\working_space\\km3irf\\src\\km3irf\\data\\aeff.fits',
#  'aeff_nocuts.fits': 'D:\\working_space\\km3irf\\src\\km3irf\\data\\aeff_nocuts.fits',
#  'all_in_one.fits': 'D:\\working_space\\km3irf\\src\\km3irf\\data\\all_in_one.fits',
#  'bkg_mu.fits': 'D:\\working_space\\km3irf\\src\\km3irf\\data\\bkg_mu.fits',
#  'bkg_nu.fits': 'D:\\working_space\\km3irf\\src\\km3irf\\data\\bkg_nu.fits',
#  'bkg_nu_knee_correction_test.fits': 'D:\\working_space\\km3irf\\src\\km3irf\\data\\bkg_nu_knee_correction_test.fits',
#  'edisp.fits': 'D:\\working_space\\km3irf\\src\\km3irf\\data\\edisp.fits',
#  'edisp_no_norm.fits': 'D:\\working_space\\km3irf\\src\\km3irf\\data\\edisp_no_norm.fits',
#  'edisp_no_smooth_no_norm.fits': 'D:\\working_space\\km3irf\\src\\km3irf\\data\\edisp_no_smooth_no_norm.fits',
#  'psf.fits': 'D:\\working_space\\km3irf\\src\\km3irf\\data\\psf.fits',
#  'psf_no_norm.fits': 'D:\\working_space\\km3irf\\src\\km3irf\\data\\psf_no_norm.fits',
# ...

# %%
data_dict["psf.fits"]
# Out:
# 'D:\\working_space\\km3irf\\src\\km3irf\\data\\psf.fits'

# %%
path_to_psf = data_dict["psf.fits"]
psf_km3 = km3irf.PSF3D.read(path_to_file=path_to_psf)

# %%
psf_km3.peek()

# %%
aeff = km3irf.DrawAeff()
aeff.peek()
