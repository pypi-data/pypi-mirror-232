# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = list(range(10))
y = [sum(x[:i]) for i in range(1, len(x) + 1)]

# %%
z = [yy**2 for yy in y]

# %%
plt.plot(x, y)

# %%
plt.plot(x, z)
